# %%
for (i in 1:5) {
    print(i)
}
# Out:
# [1] 1
# [1] 2
# [1] 3
# [1] 4
# [1] 5

# %%
sum <- 0
for (i in seq(1, 5, by = 1)) {
    sum  <- sum + i
}
sum
# Out:
# [1] 15

# %%
i <- 1
while (i <= 5) {
    print(i)
    i <- i+1
}
# Out:
# [1] 1
# [1] 2
# [1] 3
# [1] 4
# [1] 5

# %%
i <- 1
while (i <= 5) {
    i <- i + 1
    if (i==2) {
        next
    }
    print(i)
}
# Out:
# [1] 3
# [1] 4
# [1] 5
# [1] 6

# %%
i <- 1
repeat {
    print(i)
    if (i >= 5) {
        break
    }
    i <- i + 1
}
# Out:
# [1] 1
# [1] 2
# [1] 3
# [1] 4
# [1] 5

# %%
# install.packages('dplyr')
library('dplyr')
# Out:
# Attaching package: 'dplyr'
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %%
# 파이프 연산자 : %>%     컨트롤 시프트 엠

#install.packages('readxl')  # 엑셀 읽어오게 까는거
library(readxl)
# Out:
# Warning message:
# "package 'readxl' was built under R version 3.6.3"

# %%
customer_r <- read_xlsx('customer_r.xlsx')

# %%
customer_r %>% count()
# Out:
#   n
# 1 183

# %%
order_info_r <- read_xlsx('order_info_r.xlsx')

# %%
head(order_info_r)
# Out:
#   ORDER_NO           ITEM_ID RESERV_NO  QUANTITY SALES
# 1 191228137840110010 M0003   2019122805  1        17000
# 2 191228137837810010 M0001   2019122806 10       240000
# 3 191228547385810010 M0003   2019122807  2        34000
# 4 191228567831310010 M0008   2019122808  1        10000
# 5 191228567430310010 M0005   2019122809  4       140000
# 6 191228137860010010 M0005   2019122810  2        70000

# %%
dim(order_info_r)
# Out:
# [1] 391   5

# %%
summarise(order_info_r, avg = mean(SALES))
# Out:
#   avg
# 1 63828.64

# %%
summarise(order_info_r, min_value = min(SALES), max_value = max(SALES))
# Out:
#   min_value max_value
# 1 6000      552000

# %%
order_info_r %>% summarise(min_value = min(SALES), max_value = max(SALES))
# Out:
#   min_value max_value
# 1 6000      552000

# %%
reservation_r.xlsx %>% group_by(CUSTOMER_ID) %>% summarise(avg=mean(VISITOR_CNT))
# Out:
# Error in eval(lhs, parent, parent): 객체 'reservation_r.xlsx'를 찾을 수 없습니다
# Traceback:
#
# 1. reservation_r.xlsx %>% group_by(CUSTOMER_ID) %>% summarise(avg = mean(VISITOR_CNT))
# 2. eval(lhs, parent, parent)
# 3. eval(lhs, parent, parent)

# %%
order_info_r %>% filter(ITEM_ID =='M0001' & SALES >=15000)
# Out:
#    ORDER_NO           ITEM_ID RESERV_NO  QUANTITY SALES
# 1  191228137837810010 M0001   2019122806 10       240000
# 2  191230137865010010 M0001   2019123003  8       192000
# 3  191231137864710010 M0001   2019123105  8       192000
# 4  191216107839010010 M0001   2019121605  3        72000
# 5  191216107298910010 M0001   2019121606  2        48000
# 6  191217137851110010 M0001   2019121704  9       216000
# 7  19121954C005210020 M0001   2019121903  2        48000
# 8  191220674084100100 M0001   2019122002 23       552000
# 9  191220567442210010 M0001   2019122003  2        48000
# 10 191221517267210010 M0001   2019122102  8       192000
# 11 191221573879100100 M0001   2019122106  6       144000
# 12 191223578398100100 M0001   2019122302  2        48000
# 13 191224187377810010 M0001   2019122402  1        24000
# 14 191226137440910010 M0001   2019122602 11       264000
# 15 191226137864110010 M0001   2019122604 11       264000
# ...

# %%
head(order_info_r)
# Out:
#   ORDER_NO           ITEM_ID RESERV_NO  QUANTITY SALES
# 1 191228137840110010 M0003   2019122805  1        17000
# 2 191228137837810010 M0001   2019122806 10       240000
# 3 191228547385810010 M0003   2019122807  2        34000
# 4 191228567831310010 M0008   2019122808  1        10000
# 5 191228567430310010 M0005   2019122809  4       140000
# 6 191228137860010010 M0005   2019122810  2        70000

# %%
order_info_r %>% distinct(ITEM_ID)
# Out:
#    ITEM_ID
# 1  M0003
# 2  M0001
# 3  M0008
# 4  M0005
# 5  M0009
# 6  M0006
# 7  M0007
# 8  M0002
# 9  M0004
# 10 M0010

# %%
order_info_r %>% slice(2:4)
# Out:
#   ORDER_NO           ITEM_ID RESERV_NO  QUANTITY SALES
# 1 191228137837810010 M0001   2019122806 10       240000
# 2 191228547385810010 M0003   2019122807  2        34000
# 3 191228567831310010 M0008   2019122808  1        10000

# %%
table_added_row <- order_info_r %>% add_row(ORDER_NO = '1', ITEM_ID = '1', RESERV_NO = '1')

# %%
table_added_row
# Out:
#     ORDER_NO           ITEM_ID RESERV_NO  QUANTITY SALES
# 1   191228137840110010 M0003   2019122805  1        17000
# 2   191228137837810010 M0001   2019122806 10       240000
# 3   191228547385810010 M0003   2019122807  2        34000
# 4   191228567831310010 M0008   2019122808  1        10000
# 5   191228567430310010 M0005   2019122809  4       140000
# 6   191228137860010010 M0005   2019122810  2        70000
# 7   191228137860010010 M0009   2019122810  2        16000
# 8   191229107864610010 M0005   2019122901  4       140000
# 9   191229107864610010 M0009   2019122901  4        32000
# 10  191229137425710010 M0003   2019122902  2        34000
# 11  191230137860610010 M0003   2019123002  3        51000
# 12  191230137865010010 M0001   2019123003  8       192000
# 13  191230137847710020 M0005   2019123005  2        70000
# 14  191230187379710010 M0005   2019123006  1        35000
# 15  191230187379710010 M0009   2019123006  1         8000
# ...

# %%
order_info_r %>% sample_frac(0.1, replace = TRUE)
# Out:
#    ORDER_NO           ITEM_ID RESERV_NO  QUANTITY SALES
# 1  190804137255910010 M0008   2019080401  2        20000
# 2  191222181000524010 M0008   2019122205  1        10000
# 3  191011378340100100 M0001   2019101101  4        96000
# 4  191219678646100100 M0005   2019121905  2        70000
# 5  190825107839310010 M0008   2019082501  2        20000
# 6  190712372390100100 M0006   2019071201  1        25000
# 7  191125567415610010 M0009   2019112504  6        48000
# 8  191013567844610010 M0008   2019101302  2        20000
# 9  191125137301110010 M0002   2019112502  5        60000
# 10 191203107860110010 M0006   2019120304  4       100000
# 11 191221674340100100 M0008   2019122103  3        30000
# 12 190622378311100100 M0001   2019062201  2        48000
# 13 191121567397210010 M0001   2019112103  2        48000
# 14 191031573780100100 M0005   2019103102  2        70000
# 15 190920187846410010 M0006   2019092001  1        25000
# ...

# %%
order_info_r %>% select(RESERV_NO, SALES)
# Out:
#     RESERV_NO  SALES
# 1   2019122805  17000
# 2   2019122806 240000
# 3   2019122807  34000
# 4   2019122808  10000
# 5   2019122809 140000
# 6   2019122810  70000
# 7   2019122810  16000
# 8   2019122901 140000
# 9   2019122901  32000
# 10  2019122902  34000
# 11  2019123002  51000
# 12  2019123003 192000
# 13  2019123005  70000
# 14  2019123006  35000
# 15  2019123006   8000
# 16  2019123101 140000
# 17  2019123102 100000
# 18  2019123104  30000
# 19  2019123105 192000
# 20  2019123106 210000
# 21  2019123107 140000
# 22  2019123107  32000
# 23  2019121603 210000
# 24  2019121604 140000
# 25  2019121605  72000
# 26  2019121606  48000
# 27  2019121701  17000
# 28  2019121702  30000
# 29  2019121704 216000
# 30  2019121705 105000
# ... ...        ...
# 362 2019120803  25000
# 363 2019120806  10000
# 364 2019120901 216000
# 365 2019121001  36000
# 366 2019121002  70000
# 367 2019121003  12000
# 368 2019121004  70000
# 369 2019121005  20000
# 370 2019121006  24000
# ...

# %%
order_info_r %>% group_by(RESERV_NO) %>% mutate(avg=mean(SALES))
# Out:
#     ORDER_NO           ITEM_ID RESERV_NO  QUANTITY SALES  avg
# 1   191228137840110010 M0003   2019122805  1        17000  17000
# 2   191228137837810010 M0001   2019122806 10       240000 240000
# 3   191228547385810010 M0003   2019122807  2        34000  34000
# 4   191228567831310010 M0008   2019122808  1        10000  10000
# 5   191228567430310010 M0005   2019122809  4       140000 140000
# 6   191228137860010010 M0005   2019122810  2        70000  43000
# 7   191228137860010010 M0009   2019122810  2        16000  43000
# 8   191229107864610010 M0005   2019122901  4       140000  86000
# 9   191229107864610010 M0009   2019122901  4        32000  86000
# 10  191229137425710010 M0003   2019122902  2        34000  34000
# 11  191230137860610010 M0003   2019123002  3        51000  51000
# 12  191230137865010010 M0001   2019123003  8       192000 192000
# 13  191230137847710020 M0005   2019123005  2        70000  70000
# ...

# %%
order_info_r %>% group_by(RESERV_NO) %>% transmute(avg = mean(SALES))
# Out:
#     RESERV_NO  avg
# 1   2019122805  17000
# 2   2019122806 240000
# 3   2019122807  34000
# 4   2019122808  10000
# 5   2019122809 140000
# 6   2019122810  43000
# 7   2019122810  43000
# 8   2019122901  86000
# 9   2019122901  86000
# 10  2019122902  34000
# 11  2019123002  51000
# 12  2019123003 192000
# 13  2019123005  70000
# 14  2019123006  21500
# 15  2019123006  21500
# 16  2019123101 140000
# 17  2019123102 100000
# 18  2019123104  30000
# 19  2019123105 192000
# 20  2019123106 210000
# 21  2019123107  86000
# 22  2019123107  86000
# 23  2019121603 210000
# 24  2019121604 140000
# 25  2019121605  72000
# 26  2019121606  48000
# 27  2019121701  17000
# 28  2019121702  30000
# 29  2019121704 216000
# 30  2019121705 105000
# ... ...        ...
# 362 2019120803  25000
# 363 2019120806  10000
# 364 2019120901 216000
# 365 2019121001  36000
# 366 2019121002  70000
# 367 2019121003  12000
# 368 2019121004  70000
# 369 2019121005  20000
# 370 2019121006  24000
# ...

# %%
order_info_r %>% mutate_all(funs(max))
# Out:
# Warning message:
# "funs() is soft deprecated as of dplyr 0.8.0
# please use list() instead
#
# # Before:
# funs(name = f(.)
#
# # After:
# list(name = ~f(.))
# This warning is displayed once per session."
#     ORDER_NO           ITEM_ID RESERV_NO  QUANTITY SALES
# 
# 9   191229107864610010 M0009   2019122901  4        32000
# 10  191229137425710010 M0003   2019122902  2        34000
# 11  191230137860610010 M0003   2019123002  3        51000
# 12  191230137865010010 M0001   2019123003  8       192000
# 13  191230137847710020 M0005   2019123005  2        70000
# 14  191230187379710010 M0005   2019123006  1        35000
# 15  191230187379710010 M0009   2019123006  1         8000
# ...

# %%
tmp_order_info_r <- order_info_r
bind_cols(order_info_r, tmp_order_info_r)
# Out:
#     ORDER_NO           ITEM_ID RESERV_NO  QUANTITY SALES  ORDER_NO1
# 1   191228137840110010 M0003   2019122805  1        17000 191228137840110010
# 2   191228137837810010 M0001   2019122806 10       240000 191228137837810010
# 3   191228547385810010 M0003   2019122807  2        34000 191228547385810010
# 4   191228567831310010 M0008   2019122808  1        10000 191228567831310010
# 5   191228567430310010 M0005   2019122809  4       140000 191228567430310010
# 6   191228137860010010 M0005   2019122810  2        70000 191228137860010010
# 7   191228137860010010 M0009   2019122810  2        16000 191228137860010010
# 8   191229107864610010 M0005   2019122901  4       140000 191229107864610010
# 9   191229107864610010 M0009   2019122901  4        32000 191229107864610010
# 10  191229137425710010 M0003   2019122902  2        34000 191229137425710010
# 11  191230137860610010 M0003   2019123002  3        51000 191230137860610010
# ...

# %%
tmp_iris <- iris
bind_cols(iris, tmp_iris)
# Out:
#     Sepal.Length Sepal.Width Petal.Length Petal.Width Species   Sepal.Length1
# 1   5.1          3.5         1.4          0.2         setosa    5.1
# 2   4.9          3.0         1.4          0.2         setosa    4.9
# 3   4.7          3.2         1.3          0.2         setosa    4.7
# 4   4.6          3.1         1.5          0.2         setosa    4.6
# 5   5.0          3.6         1.4          0.2         setosa    5.0
# 6   5.4          3.9         1.7          0.4         setosa    5.4
# 7   4.6          3.4         1.4          0.3         setosa    4.6
# 8   5.0          3.4         1.5          0.2         setosa    5.0
# 9   4.4          2.9         1.4          0.2         setosa    4.4
# 10  4.9          3.1         1.5          0.1         setosa    4.9
# 11  5.4          3.7         1.5          0.2         setosa    5.4
# 12  4.8          3.4         1.6          0.2         setosa    4.8
# 13  4.8          3.0         1.4          0.1         setosa    4.8
# ...

# %%
iris3 <- cbind(iris, tmp_iris)
iris3
# Out:
#     Sepal.Length Sepal.Width Petal.Length Petal.Width Species   Sepal.Length
# 1   5.1          3.5         1.4          0.2         setosa    5.1
# 2   4.9          3.0         1.4          0.2         setosa    4.9
# 3   4.7          3.2         1.3          0.2         setosa    4.7
# 4   4.6          3.1         1.5          0.2         setosa    4.6
# 5   5.0          3.6         1.4          0.2         setosa    5.0
# 6   5.4          3.9         1.7          0.4         setosa    5.4
# 7   4.6          3.4         1.4          0.3         setosa    4.6
# 8   5.0          3.4         1.5          0.2         setosa    5.0
# 9   4.4          2.9         1.4          0.2         setosa    4.4
# 10  4.9          3.1         1.5          0.1         setosa    4.9
# 11  5.4          3.7         1.5          0.2         setosa    5.4
# 12  4.8          3.4         1.6          0.2         setosa    4.8
# 13  4.8          3.0         1.4          0.1         setosa    4.8
# ...
